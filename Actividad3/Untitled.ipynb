# %%
# Cargar a la memoria de trabajo las bibliotecas: Pandas (manejo de datos, 
# Numpy (numerical python) y la biblioteca de gráficas Matplotlib
# Se asignan nombres cortos.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1= pd.read_csv('junio22.txt', skiprows=5, sep='\s+')
df2= pd.read_csv('diciembre22.txt', skiprows=5, sep='\s+')
df1.columns = ['PRES','HGHT','TEMP','DWPT','RELH','MIXR','DRCT','SKNT','THTA','THTE','THTV']
df2.columns = ['PRES','HGHT','TEMP','DWPT','RELH','MIXR','DRCT','SKNT','THTA','THTE','THTV']

# %%
df1
# Out:
#      PRES   HGHT  TEMP  DWPT  RELH  MIXR  DRCT  SKNT    THTA    THTE    THTV
# 0   974.0    356  29.6  11.6    33  8.88   221     5   305.0   332.0   306.7
# 1   925.0    811  26.2  10.2    37  8.51   225    12   306.1   332.1   307.7
# 2   902.0   1030  24.4   9.3    38  8.22   230    16   306.5   331.6   308.0
# 3   850.0   1548  20.2   7.2    43  7.55   230    14   307.3   330.6   308.7
# 4   712.0   3043   8.0  -1.0    53  5.02   235     9   309.8   325.7   310.7
# 5   700.0   3183   7.0  -2.0    53  4.74   235     8   310.2   325.3   311.1
# 6   683.0   3384   5.5  -3.5    52  4.34   235     7   310.7   324.6   311.5
# 7   645.0   3851   2.0  -7.0    51  3.52   212    13   311.9   323.3   312.5
# 8   642.0   3889   1.8  -8.1    48  3.25   210    14   312.0   322.6   312.6
# 9   595.0   4499  -1.9 -25.9    14  0.78   228    16   314.6   317.4   314.8
# 10  559.0   4992  -6.1 -13.1    58  2.51   243    17   315.3   323.7   315.8
# ...

# %%
df2
# Out:
#       PRES   HGHT  TEMP   DWPT  RELH  MIXR  DRCT  SKNT   THTA   THTE   THTV
# 0   1012.0    217   9.4    2.4    62  4.52   317    12  281.6  294.4  282.4
# 1   1002.0    300   8.6    6.2    85  5.97   311    12  281.6  298.2  282.6
# 2   1000.0    317   8.4    6.0    85  5.90   310    12  281.6  298.0  282.6
# 3    943.0    800   5.4    3.7    89  5.32   284    13  283.3  298.3  284.2
# 4    930.0    914   6.6    4.1    84  5.55   277    13  285.6  301.4  286.6
# 5    925.0    958   6.4    3.9    84  5.50   275    13  285.9  301.5  286.8
# 6    920.0   1002   6.2    3.7    84  5.45   270    13  286.1  301.7  287.0
# 7    850.0   1648   3.4    0.8    83  4.79   275    16  289.7  303.7  290.5
# 8    841.0   1734   3.0    0.4    83  4.71   276    16  290.2  303.9  291.0
# 9    772.0   2424   0.2  -15.8    29  1.45   282    20  294.3  298.9  294.6
# 10   753.0   2624  -0.9  -16.9    29  1.36   284    21  295.2  299.6  295.5
# ...

# %%
df1 = df1.drop(df1.index[len(df1)-2])
df2 = df2.drop(df2.index[len(df2)-1])

# %%
df1.dtypes
# Out:
# PRES    float64
# HGHT      int64
# TEMP    float64
# DWPT    float64
# RELH      int64
# MIXR    float64
# DRCT      int64
# SKNT      int64
# THTA    float64
# THTE    float64
# THTV    float64
# dtype: object

# %%
df2.dtypes
# Out:
# PRES    float64
# HGHT      int64
# TEMP    float64
# DWPT    float64
# RELH      int64
# MIXR    float64
# DRCT      int64
# SKNT      int64
# THTA    float64
# THTE    float64
# THTV    float64
# dtype: object

# %%
#Hace que los int64 se conviertan en número
columnas = ['HGHT','RELH','DRCT','SKNT']
df1[columnas]= df1[columnas].apply(pd.to_numeric,errors='coerce', axis=1)
df2[columnas]= df2[columnas].apply(pd.to_numeric,errors='coerce', axis=1)

# %%
#Gráfica de la variación de la presión con respecto a la altura para junio
df01 = df1[['HGHT','PRES']]
plt.figure(); df01.plot(x='PRES');plt.legend(loc='best')
plt.title('Variación de la Presión con Respecto a la Altura para junio')
plt.xlim([0,1000])
plt.xlabel('Presión (hPa)')
plt.ylabel('Altura (m)')
plt.grid(True)
plt.show()

# %%
#Gráfica de la variación de la presión con respecto a la altura para diciembre
df02 = df2[['HGHT','PRES']]
plt.figure(); df02.plot(x='PRES');plt.legend(loc='best')
plt.title('Variación de la Presión con Respecto a la Altura para diciembre')
plt.xlim([0,1000])
plt.xlabel('Presión (hPa)')
plt.ylabel('Altura (m)')
plt.grid(True)
plt.show()

# %%
#Gráfica de la variación de la temperatura con respecto a la altura para junio
df01 = df1[['HGHT','TEMP']]
plt.figure(); df01.plot(x='TEMP');plt.legend(loc='best')
plt.title('Variación de la temperatura con respecto a la altura para junio')
plt.xlim([-26.1,30])
plt.xlabel('Temperatura (C)')
plt.ylabel('Altura (m)')
plt.grid(True)
plt.show()

# %%
#Gráfica de la variación de la temperatura con respecto a la altura para diciembre
df02 = df2[['HGHT','TEMP']]
plt.figure(); df02.plot(x='TEMP');plt.legend(loc='best')
plt.title('Variación de la temperatura con respecto a la altura para diciembre')
plt.xlim([-77,10])
plt.xlabel('Temperatura (C)')
plt.ylabel('Altura (m)')
plt.grid(True)
plt.show()

# %%
#Gráfica de variación de la temperatura y de la temperatura de rocío para junio
plt.plot(df1['TEMP'], df1['HGHT'], "red", label='TEMP')
plt.plot(df1['DWPT'], df1['HGHT'], "blue", label='DWPT')
plt.legend(loc='upper right')
plt.title("Gráfica Temperatura y Temperatura de rocío con respecto a Altura para junio")
plt.xlabel("Temperatura (°C)")
plt.ylabel("Altura (m)")
plt.grid(True)

plt.show()

# %%
#Gráfica de variación de la temperatura y de la temperatura de rocío para diciembre
plt.plot(df2['TEMP'], df2['HGHT'], "red", label='TEMP')
plt.plot(df2['DWPT'], df2['HGHT'], "blue", label='DWPT')
plt.legend(loc='upper right')
plt.title("Gráfica Temperatura y Temperatura de rocío con respecto a Altura para diciembre")
plt.xlabel("Temperatura (°C)")
plt.ylabel("Altura (m)")
plt.grid(True)

plt.show()

# %%
#Gráfica de la variación de la rapidez de los vientos con respecto a la altura para junio
df01 = df1[['HGHT','SKNT']]
plt.figure(); df01.plot(x='SKNT');plt.legend(loc='best')
plt.title('Variación de la rapidez de los vientos con respecto a la altura para junio')
plt.xlim([0,50])
plt.xlabel('Rapidez de los vientos (knot)')
plt.ylabel('Altura (m)')
plt.grid(True)
plt.show()

# %%
#Gráfica de la variación de la rapidez de los vientos con respecto a la altura para diciembre
df02 = df2[['HGHT','SKNT']]
plt.figure(); df02.plot(x='SKNT');plt.legend(loc='best')
plt.title('Variación de la rapidez de los vientos con respecto a la altura para diciembre')
plt.xlim([0,67])
plt.xlabel('Rapidez de los vientos (knot)')
plt.ylabel('Altura (m)')
plt.grid(True)
plt.show()

# %%
#Gráfica de la variación de la humedad relativa con respecto a la altura para junio
df01 = df1[['HGHT','RELH']]
plt.figure(); df01.plot(x='RELH');plt.legend(loc='best')
plt.title('Variación de la humedad relativa con respecto a la altura para junio')
plt.xlim([0,70])
plt.xlabel('Humedad relativa (%)')
plt.ylabel('Altura (m)')
plt.grid(True)
plt.show()

# %%
#Gráfica de la variación de la hmedad relativa con respecto a la altura para diciembre
df02 = df2[['HGHT','RELH']]
plt.figure(); df02.plot(x='RELH');plt.legend(loc='best')
plt.title('Variación de la humedad relativa con respecto a la altura para diciembre')
plt.xlim([0,95])
plt.xlabel('Humedad relativa (%)')
plt.ylabel('Altura (m)')
plt.grid(True)
plt.show()
