# %%
import pandas as pd
import numpy as np
from datetime import datetime
import seaborn as sns

# %%
df1= pd.read_csv('sargento-270218.csv', header=None, skiprows=2, sep=',')
df2= pd.read_csv('sargento-salinidad-270218.csv', header=None, skiprows=2, sep=',')

# %%
df1.columns = ['NO','Date','abs','temp','Met']
df2.columns = ['NO','Date','CondH','temp','Conduc','sal']

# %%
df1.head()
# Out:
#    NO                 Date      abs    temp    Met
# 0   1  02/04/2018 09:45:00  108.068  17.094  0.060
# 1   2  02/04/2018 10:00:00  107.815  16.903  0.035
# 2   3  02/04/2018 10:15:00  107.791  16.903  0.032
# 3   4  02/04/2018 10:30:00  107.791  16.903  0.032
# 4   5  02/04/2018 10:45:00  107.791  16.903  0.032

# %%
df2.head()
# Out:
#    NO                 Date    CondH   temp   Conduc      sal
# 0   2  02/04/2018 09:45:00  50617.2  17.33  59362.4  39.7235
# 1   3  02/04/2018 10:00:00  50646.3  17.23  59526.8  39.8482
# 2   4  02/04/2018 10:15:00  50772.9  17.17  59753.7  40.0203
# 3   5  02/04/2018 10:30:00  51007.8  17.14  60068.6  40.2595
# 4   6  02/04/2018 10:45:00  50958.7  17.11  60050.6  40.2458

# %%
# Convertir la cadena de caracteres 'Date' en variable temporal 'NDate'
df1['Ndate'] = pd.to_datetime(df1['Date'], format='%m/%d/%Y %H:%M:%S')
df1['month'] = df1['Ndate'].dt.month
df1.head()
# Out:
#    NO                 Date      abs    temp    Met               Ndate  month
# 0   1  02/04/2018 09:45:00  108.068  17.094  0.060 2018-02-04 09:45:00      2
# 1   2  02/04/2018 10:00:00  107.815  16.903  0.035 2018-02-04 10:00:00      2
# 2   3  02/04/2018 10:15:00  107.791  16.903  0.032 2018-02-04 10:15:00      2
# 3   4  02/04/2018 10:30:00  107.791  16.903  0.032 2018-02-04 10:30:00      2
# 4   5  02/04/2018 10:45:00  107.791  16.903  0.032 2018-02-04 10:45:00      2

# %%
# Convertir la cadena de caracteres 'Date' en variable temporal 'NDate'
df2['Ndate'] = pd.to_datetime(df2['Date'], format='%m/%d/%Y %H:%M:%S')
df2['month'] = df2['Ndate'].dt.month
df2.head()
# Out:
#    NO                 Date    CondH   temp   Conduc      sal  \
# 0   2  02/04/2018 09:45:00  50617.2  17.33  59362.4  39.7235
# 1   3  02/04/2018 10:00:00  50646.3  17.23  59526.8  39.8482
# 2   4  02/04/2018 10:15:00  50772.9  17.17  59753.7  40.0203
# 3   5  02/04/2018 10:30:00  51007.8  17.14  60068.6  40.2595
# 4   6  02/04/2018 10:45:00  50958.7  17.11  60050.6  40.2458
#
#                 Ndate  month
# 0 2018-02-04 09:45:00      2
# 1 2018-02-04 10:00:00      2
# 2 2018-02-04 10:15:00      2
# 3 2018-02-04 10:30:00      2
# 4 2018-02-04 10:45:00      2

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(x="month", y="Met", data=df1)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(x="month", y="sal", data=df2)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(x="month", y="temp", data=df2)
plt.show()

# %%
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

g = sns.jointplot("CondH", "sal", data=df2, kind="reg",
                   color="r", size=7)
plt.show(g)

# %%
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

g = sns.jointplot("CondH", "temp", data=df2, kind="reg",
                   color="r", size=7)
plt.show(g)

# %%
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

g = sns.jointplot("sal", "temp", data=df2, kind="reg",
                   color="r", size=7)
plt.show(g)

# %%
plt.figure(); df2.CondH.plot(); plt.legend(loc='best')
plt.title("")
plt.ylabel("Tiempo")
plt.grid(True)
plt.show()

# %%
plt.figure(); df2.sal.plot(); plt.legend(loc='best')
plt.title("")
plt.ylabel("Tiempo")
plt.grid(True)
plt.show()

# %%
plt.figure(); df2.temp.plot(); plt.legend(loc='best')
plt.title("")
plt.ylabel("Tiempo")
plt.grid(True)
plt.show()

# %%
fig, ax1 = plt.subplots()
a=df1.Met
b=df2.sal
t=df1.Date
ax1.plot(t, a, 'b-')
ax1.set_xlabel('time (s)')

ax2 = ax1.twinx()
ax2.plot(t, b, 'r.')
ax2.set_ylabel('nivel del mar y salanidad', color='r')
fig.tight_layout()

plt.show()

# %%
fig, ax1 = plt.subplots()
a=df1.Met
b=df2.temp
t=df1.Date
ax1.plot(t, a, 'b-')
ax1.set_xlabel('time (s)')

ax2 = ax1.twinx()
ax2.plot(t, b, 'r.')
ax2.set_ylabel('nivel del mar y temperatura', color='r')
fig.tight_layout()

plt.show()

# %%
fig, ax1 = plt.subplots()
a=df1.Met
b=df2.sal
t=df1.Date
ax1.plot(t, a, 'b-')
ax1.set_xlabel('time (s)')

ax2 = ax1.twinx()
ax2.plot(t, b, 'r.')
ax2.set_ylabel('nivel del mar y salanidad', color='r')
xlim=([1000,1500])
fig.tight_layout()

plt.show()

# %%
fig, ax1 = plt.subplots()
a=df1.Met
b=df2.temp
t=df1.Date
ax1.plot(t, a, 'b-')
ax1.set_xlabel('time (s)')

ax2 = ax1.twinx()
ax2.plot(t, b, 'r.')
ax2.set_ylabel('nivel del mar y temperatura', color='r')
fig.tight_layout()
xlim=([1000,1500])

plt.show()
